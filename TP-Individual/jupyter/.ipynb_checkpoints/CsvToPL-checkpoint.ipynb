# %%
import pandas as pd

path = "D:/Projetos/Uni/3ano/2sem/SRCR/Dados/CSV/"

fl = pd.read_csv(path+"NomesCsvs.txt",header = None)

basefile = open(path+"BaseConhecimento.pl","w", encoding="utf-8")

for index,row in fl.iterrows():
    print("---------------------NOVA DF---------------------")
    print(row[0])
    df = pd.read_csv(filepath+str(row[0]))
    for index2,row2 in df.iterrows():
        basefile.write('paragem(')
        basefile.write(str(row2[7])+","+str(index2+1)+","+str(row2[0])+","+str(row2[1])+","+str(row2[2])+",'"+str(row2[3])+"','"+str(row2[4])+"','"+str(row2[5])+"','"+str(row2[6])+"',"+str(row2[8])+",'"+str(row2[9])+"','"+str(row2[10])+"'")
        basefile.write(").")
        basefile.write("\n")
    
basefile.close()
# Out:
# ---------------------NOVA DF---------------------
# lista_adjacencias_paragens_01.csv
# ---------------------NOVA DF---------------------
# lista_adjacencias_paragens_02.csv
# ---------------------NOVA DF---------------------
# lista_adjacencias_paragens_06.csv
# ---------------------NOVA DF---------------------
# lista_adjacencias_paragens_07.csv
# ---------------------NOVA DF---------------------
# lista_adjacencias_paragens_10.csv
# ---------------------NOVA DF---------------------
# lista_adjacencias_paragens_11.csv
# ---------------------NOVA DF---------------------
# lista_adjacencias_paragens_12.csv
# ---------------------NOVA DF---------------------
# lista_adjacencias_paragens_13.csv
# ---------------------NOVA DF---------------------
# lista_adjacencias_paragens_15.csv
# ---------------------NOVA DF---------------------
# lista_adjacencias_paragens_23.csv
# ---------------------NOVA DF---------------------
# lista_adjacencias_paragens_101.csv
# ...
